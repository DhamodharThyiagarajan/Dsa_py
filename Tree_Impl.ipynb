# %% [markdown]
# <a href="https://colab.research.google.com/github/DhamodharThyiagarajan/Dsa_py/blob/main/Tree_Impl.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class TreeNode:
  def __init__(self,data):
    self.data=data
    self.children=[]

  def add_child(self,child):
    self.children.append(child)

  def print_tree(self,level=0):
    indent=" "*level+"|_" if level>0 else ""
    print(indent+str(self.data))

    for child in self.children:
      child.print_tree(level+1)
root=TreeNode("C:ROOT")
f1=TreeNode("Desktop")
f2=TreeNode("Documents")
f3=TreeNode("Download")
root.add_child(f1)
root.add_child(f2)
root.add_child(f3)
f1.add_child(TreeNode("vk.jpg"))
f2.add_child(TreeNode("resume.pdf"))
f3.add_child(TreeNode("python.exe"))
root.print_tree()
# Out:
# C:ROOT
#  |_Desktop
#   |_vk.jpg
#  |_Documents
#   |_resume.pdf
#  |_Download
#   |_python.exe

# %%
class BinaryTreeNode:
  def __init__(self,data):
    self.data=data
    self.left=None
    self.right=None

  def inorder(self):
    if self.left:
      self.left.inorder()
    print(self.data)#Root
    if self.right:
      self.right.inorder()

root=BinaryTreeNode("A")
root.left=BinaryTreeNode("B")
root.right=BinaryTreeNode("C")
root.left.left=BinaryTreeNode("E")
root.left.right=BinaryTreeNode('F')
root.right.left=BinaryTreeNode('G')

root.inorder()
# Out:
# E
# B
# F
# A
# G
# C

# %%
class BSTNode:
    def __init__(self, key):
        self.val = key
        self.left = None
        self.right = None

class BinarySearchTree:
    def __init__(self):
        self.root = None
    def insert(self, key):
        if self.root is None:
            self.root = BSTNode(key)
        else:
            self._insert_recursive(self.root, key)

    def _insert_recursive(self, current, key):
        if key < current.val:
            if current.left is None:
                current.left = BSTNode(key)
            else:
                self._insert_recursive(current.left, key)
        elif key > current.val:
            if current.right is None:
                current.right = BSTNode(key)
            else:
                self._insert_recursive(current.right, key)

    def inorder(self, node):
        # LEFT -> ROOT -> RIGHT (Outputs sorted data)
        if node:
            self.inorder(node.left)
            print(node.val, end=" ")
            self.inorder(node.right)

tree = BinarySearchTree()
values_to_insert = [50, 30, 20, 40, 70, 60, 80]
for val in values_to_insert:
    tree.insert(val)
print(f"Inserted values: {values_to_insert}\n")

tree.inorder(tree.root)
# Out:
# Inserted values: [50, 30, 20, 40, 70, 60, 80]
#
# 20 30 40 50 60 70 80
